# %%
# %timeit for i in range(1000): i*i
# Out:
# 29.3 μs ± 5.15 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# '''python
# %timeit for i in range(1000): i*i
# '''

# %% [markdown]
# ## Примеры экспериментов
# - alice experiment cern
# - super kamiakande
# - juno experiment
# - калининская АЭС
# - свойства белков
#
# Необходимо обрабатывать большое кол-во данных. Для чего используется C++.
