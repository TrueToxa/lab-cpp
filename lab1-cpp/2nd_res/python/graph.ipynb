# %% [markdown]
# # Поиск

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Линейный поиск
# $\mathcal{O}(N)$

# %%
df = pd.read_csv('../csv/find_num_in_array.csv', delimiter=';')

plt.figure(figsize=(10,6))

sns.regplot(data=df, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 95)
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title('Линейный поиск')
plt.xlabel('$N$')
plt.ylabel('$\\tau,\\ \\text{ns}$')
plt.grid(True, alpha=0.3)
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('find_num_in_array_lin.png')
plt.show()

# %%
df = pd.read_csv('../csv/find_num_in_array.csv', delimiter=';')

plt.figure(figsize=(10,6))

sns.regplot(x=np.log10(df['n']), y=np.log10(df['t_ns']), order=1, x_estimator=np.mean, ci = 95)
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title('Линейный поиск')
plt.xlabel('$\\log_{10}{N}$')
plt.ylabel('$\\log_{10}{(\\tau/\\text{ns})}$')
plt.grid(True, alpha=0.3)
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('find_num_in_array_log.png')
plt.show()

# %% [markdown]
# ## Бинарный поиск
# $\mathcal{O}(\log(N))$

# %%
df = pd.read_csv('../csv/find_num_in_sorted_array.csv', delimiter=';')

plt.figure(figsize=(10,6))

sns.regplot(data=df, x="n", y="t_ns", order=1, x_estimator=np.mean, logx = 1, ci = 98)
# plt.yscale('log')
# plt.xscale('log')

plt.title('Бинарный поиск')
plt.xlabel('$N$')
plt.ylabel('$\\tau,\\ \\text{ns}$')
plt.grid(True, alpha=0.3)
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('find_num_in_sorted_array.png')
plt.show()

# %%
df = pd.read_csv('../csv/find_num_in_sorted_array.csv', delimiter=';')

plt.figure(figsize=(10,6))

sns.regplot(data=df, x="n", y="t_ns", order=1, x_estimator=np.mean, logx = 1, ci = 100)
# plt.yscale('log')
plt.xscale('log')

plt.title('Бинарный поиск')
plt.xlabel('$N$')
plt.ylabel('$\\tau,\\ \\text{ns}$')
plt.grid(True, alpha=0.3)
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('find_num_in_sorted_array_linear.png')
plt.show()

# %% [markdown]
# # Сумма двух

# %% [markdown]
# ## Полный перебор
# $\mathcal{O}(N^2)$

# %%
df = pd.read_csv('../csv/find_pair_with_sum.csv', delimiter=';')

plt.figure(figsize=(10,6))

sns.regplot(data=df, x="n", y="t_ns", order=2, x_estimator=np.mean, ci = 0)
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title('Линейный поиск')
plt.xlabel('$N$')
plt.ylabel('$\\tau,\\ \\text{ns}$')
plt.grid(True, alpha=0.3)
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('find_pair_with_sum.png')
plt.show()

# %%
df = pd.read_csv('../csv/find_pair_with_sum.csv', delimiter=';')
plt.figure(figsize=(10,6))

sns.regplot(x=np.log10(df['n']), y=np.log10(df['t_ns']), order=1, ci = 95, scatter=False)
sns.boxplot(x=np.log10(df['n']), y=np.log10(df['t_ns']), native_scale=1)
# кресты ошибок - доверительный интервал 95%

plt.title('Поиск элементов данной суммы в упорядоченном массиве\n Логарифмический масштаб')
plt.xlabel('$\\log_{10}{N}$')
plt.ylabel('$\\log_{10}{(\\tau/\\text{ns})}$')
plt.grid(True, alpha=0.3)
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('find_pair_with_sum_log.png')
plt.show()

# %% [markdown]
# ## Поиск в упорядоченном массиве
# $\mathcal{O}(N)$

# %%
df = pd.read_csv('../csv/find_pair_with_sum_in_sorted_array.csv', delimiter=';')

plt.figure(figsize=(10,6))

sns.regplot(data=df, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 95)
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title('Поиск элементов данной суммы в упорядоченном массиве\n Линейный масштаб')
plt.xlabel('$N$')
plt.ylabel('$\\tau,\\ \\text{ns}$')
plt.grid(True, alpha=0.3)
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('find_pair_with_sum_in_sorted_array_lin.png')
plt.show()

# %%
df = pd.read_csv('../csv/find_pair_with_sum_in_sorted_array.csv', delimiter=';')

plt.figure(figsize=(10,6))

sns.regplot(x=np.log10(df['n']), y=np.log10(df['t_ns']), order=1, x_estimator=np.mean, ci = 95)
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title('Поиск элементов данной суммы в упорядоченном массиве\n Логарифмический масштаб')
plt.xlabel('$\\log_{10}{N}$')
plt.ylabel('$\\log_{10}{(\\tau/\\text{ns})}$')
plt.grid(True, alpha=0.3)
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('find_pair_with_sum_in_sorted_array_log.png')
plt.show()

# %% [markdown]
# # Часто используемый элемент

# %% [markdown]
# ## Равномерное распределение элементов и данных

# %%
dfO = pd.read_csv('../csv/O11.csv', delimiter=';')
dfA = pd.read_csv('../csv/A11.csv', delimiter=';')
dfB = pd.read_csv('../csv/B11.csv', delimiter=';')
dfC = pd.read_csv('../csv/C11.csv', delimiter=';')

plt.figure(figsize=(10,6))

sns.regplot(data=dfO, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 100, label = "O",  line_kws={'linestyle': '-'})
sns.regplot(data=dfA, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 100, label = "A",  line_kws={'linestyle': '-'})
sns.regplot(data=dfB, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 100, label = "B", line_kws={'linestyle': '-.'})
sns.regplot(data=dfC, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 100, label = "C",  line_kws={'linestyle': ':'})
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title('Реализация find_ABC в сравнении с find_O\n равномерные данные и запросы \n Линейный масштаб')
plt.xlabel('$N$')
plt.ylabel('$\\tau,\\ \\text{ns}$')
plt.grid(True, alpha=0.3)
plt.legend()
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('abc_test_11.png')
plt.show()

# %%
# df = pd.read_csv('../csv/find_pair_with_sum_in_sorted_array.csv', delimiter=';')

plt.figure(figsize=(10,6))

# sns.regplot(x=np.log10(df['n']), y=np.log10(df['t_ns']), order=1, x_estimator=np.mean, ci = 95)
sns.regplot(x=np.log10(dfO['n']), y=np.log10(dfO['t_ns']), order=1, x_estimator=np.mean, ci = 95, label = "O",  line_kws={'linestyle': '-'})
sns.regplot(x=np.log10(dfA['n']), y=np.log10(dfA['t_ns']), order=1, x_estimator=np.mean, ci = 95, label = "A",  line_kws={'linestyle': '-'})
sns.regplot(x=np.log10(dfB['n']), y=np.log10(dfB['t_ns']), order=1, x_estimator=np.mean, ci = 95, label = "B", line_kws={'linestyle': '-.'})
sns.regplot(x=np.log10(dfC['n']), y=np.log10(dfC['t_ns']), order=1, x_estimator=np.mean, ci = 95, label = "C",  line_kws={'linestyle': ':'})
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title('Реализация find_ABC в сравнении с find_O\n равномерные данные и запросы\n Логарифмический масштаб')
plt.xlabel('$\\log_{10}{N}$')
plt.ylabel('$\\log_{10}{(\\tau/\\text{ns})}$')
plt.grid(True, alpha=0.3)
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('abc_test_11_log.png')
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.regplot(x=dfO['n'], y=dfO['t_ns']-dfO['t_ns'], order=1, x_estimator=np.mean, ci = 100, label = "O",  line_kws={'linestyle': '-'}, scatter=1)
sns.regplot(x=dfO['n'], y=dfO['t_ns']-dfA['t_ns'], order=2, x_estimator=np.mean, ci = 95, label = "A",  line_kws={'linestyle': '-'})
sns.regplot(x=dfO['n'], y=dfO['t_ns']-dfB['t_ns'], order=2, x_estimator=np.mean, ci = 95, label = "B", line_kws={'linestyle': '-.'})
sns.regplot(x=dfO['n'], y=dfO['t_ns']-dfC['t_ns'], order=2, x_estimator=np.mean, ci = 95, label = "C",  line_kws={'linestyle': ':'})
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title(' Разница времен работы find_ABC и find_O\n равномерные данные и запросы\n Линейный масштаб')
plt.xlabel('$N$')
plt.ylabel('$\\tau,\\ \\text{ns}$')
plt.grid(True, alpha=0.3)
plt.legend()
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('abc_test_11_OX_diff.png')
plt.show()

# %% [markdown]
# ## Неравномерный запрос данных

# %%
dfO = pd.read_csv('../csv/O10.csv', delimiter=';')
dfA = pd.read_csv('../csv/A10.csv', delimiter=';')
dfB = pd.read_csv('../csv/B10.csv', delimiter=';')
dfC = pd.read_csv('../csv/C10.csv', delimiter=';')

plt.figure(figsize=(10,6))

sns.regplot(data=dfO, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 100, label = "O",  line_kws={'linestyle': '-'}, scatter=1)
sns.regplot(data=dfA, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 95, label = "A",  line_kws={'linestyle': '-'})
sns.regplot(data=dfB, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 95, label = "B", line_kws={'linestyle': '-.'})
sns.regplot(data=dfC, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 95, label = "C",  line_kws={'linestyle': ':'})
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title('Реализация find_ABC в сравнении с find_O\n равномерные данные и неравномерные запросы\n Линейный масштаб')
plt.xlabel('$N$')
plt.ylabel('$\\tau,\\ \\text{ns}$')
plt.grid(True, alpha=0.3)
plt.legend()
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('abc_test_10.png')
plt.show()

# %%
# df = pd.read_csv('../csv/find_pair_with_sum_in_sorted_array.csv', delimiter=';')

plt.figure(figsize=(10,6))

# sns.regplot(x=np.log10(df['n']), y=np.log10(df['t_ns']), order=1, x_estimator=np.mean, ci = 95)
sns.regplot(x=np.log10(dfO['n']), y=np.log10(dfO['t_ns']), order=1, x_estimator=np.mean, ci = 95, label = "O",  line_kws={'linestyle': '-'})
sns.regplot(x=np.log10(dfA['n']), y=np.log10(dfA['t_ns']), order=1, x_estimator=np.mean, ci = 95, label = "A",  line_kws={'linestyle': '-'})
sns.regplot(x=np.log10(dfB['n']), y=np.log10(dfB['t_ns']), order=1, x_estimator=np.mean, ci = 95, label = "B", line_kws={'linestyle': '-.'})
sns.regplot(x=np.log10(dfC['n']), y=np.log10(dfC['t_ns']), order=1, x_estimator=np.mean, ci = 95, label = "C",  line_kws={'linestyle': ':'})
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title('Реализация find_ABC в сравнении с find_O\n равномерные данные и неравномерные запросы\n Логарифмический масштаб')
plt.xlabel('$\\log_{10}{N}$')
plt.ylabel('$\\log_{10}{(\\tau/\\text{ns})}$')
plt.grid(True, alpha=0.3)
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('abc_test_10_log.png')
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.regplot(x=dfO['n'], y=dfO['t_ns']-dfO['t_ns'], order=1, x_estimator=np.mean, ci = 100, label = "O",  line_kws={'linestyle': '-'}, scatter=1)
sns.regplot(x=dfO['n'], y=dfO['t_ns']-dfA['t_ns'], order=2, x_estimator=np.mean, ci = 95, label = "A",  line_kws={'linestyle': '-'})
sns.regplot(x=dfO['n'], y=dfO['t_ns']-dfB['t_ns'], order=2, x_estimator=np.mean, ci = 95, label = "B", line_kws={'linestyle': '-.'})
sns.regplot(x=dfO['n'], y=dfO['t_ns']-dfC['t_ns'], order=2, x_estimator=np.mean, ci = 95, label = "C",  line_kws={'linestyle': ':'})
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title(' Разница времен работы find_ABC и find_O \n равномерные данные и неравномерные запросы\n Линейный масштаб')
plt.xlabel('$N$')
plt.ylabel('$\\tau,\\ \\text{ns}$')
plt.grid(True, alpha=0.3)
plt.legend()
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('abc_test_10_OX_diff.png')
plt.show()

# %% [markdown]
# ## Неравномерные данные

# %%
dfO = pd.read_csv('../csv/O01.csv', delimiter=';')
dfA = pd.read_csv('../csv/A01.csv', delimiter=';')
dfB = pd.read_csv('../csv/B01.csv', delimiter=';')
dfC = pd.read_csv('../csv/C01.csv', delimiter=';')

plt.figure(figsize=(10,6))

sns.regplot(data=dfO, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 100, label = "O",  line_kws={'linestyle': '-'}, scatter=1)
sns.regplot(data=dfA, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 95, label = "A",  line_kws={'linestyle': '-'})
sns.regplot(data=dfB, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 95, label = "B", line_kws={'linestyle': '-.'})
sns.regplot(data=dfC, x="n", y="t_ns", order=1, x_estimator=np.mean, ci = 95, label = "C",  line_kws={'linestyle': ':'})
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title('Реализация find_ABC в сравнении с find_O\n неравномерные данные и равномерные запросы\n Линейный масштаб')
plt.xlabel('$N$')
plt.ylabel('$\\tau,\\ \\text{ns}$')
plt.grid(True, alpha=0.3)
plt.legend()
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('abc_test_01.png')
plt.show()

# %%
# df = pd.read_csv('../csv/find_pair_with_sum_in_sorted_array.csv', delimiter=';')

plt.figure(figsize=(10,6))

# sns.regplot(x=np.log10(df['n']), y=np.log10(df['t_ns']), order=1, x_estimator=np.mean, ci = 95)
sns.regplot(x=np.log10(dfO['n']), y=np.log10(dfO['t_ns']), order=1, x_estimator=np.mean, ci = 95, label = "O",  line_kws={'linestyle': '-'})
sns.regplot(x=np.log10(dfA['n']), y=np.log10(dfA['t_ns']), order=1, x_estimator=np.mean, ci = 95, label = "A",  line_kws={'linestyle': '-'})
sns.regplot(x=np.log10(dfB['n']), y=np.log10(dfB['t_ns']), order=1, x_estimator=np.mean, ci = 95, label = "B", line_kws={'linestyle': '-.'})
sns.regplot(x=np.log10(dfC['n']), y=np.log10(dfC['t_ns']), order=1, x_estimator=np.mean, ci = 95, label = "C",  line_kws={'linestyle': ':'})
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title('Реализация find_ABC в сравнении с find_O\n неравномерные данные и равномерные запросы\n Логарифмический масштаб')
plt.xlabel('$\\log_{10}{N}$')
plt.ylabel('$\\log_{10}{(\\tau/\\text{ns})}$')
plt.grid(True, alpha=0.3)
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('abc_test_01_log.png')
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.regplot(x=dfO['n'], y=dfO['t_ns']-dfO['t_ns'], order=1, x_estimator=np.mean, ci = 100, label = "O",  line_kws={'linestyle': '-'}, scatter=1)
sns.regplot(x=dfO['n'], y=dfO['t_ns']-dfA['t_ns'], order=2, x_estimator=np.mean, ci = 95, label = "A",  line_kws={'linestyle': '-'})
sns.regplot(x=dfO['n'], y=dfO['t_ns']-dfB['t_ns'], order=2, x_estimator=np.mean, ci = 95, label = "B", line_kws={'linestyle': '-.'})
sns.regplot(x=dfO['n'], y=dfO['t_ns']-dfC['t_ns'], order=2, x_estimator=np.mean, ci = 95, label = "C",  line_kws={'linestyle': ':'})
# кресты ошибок - доверительный интервал 95%

# plt.yscale('log')
# plt.xscale('log')

plt.title('Разница времен работы find_ABC и find_O \n неравномерные данные и равномерные запросы \n Линейный масштаб')
plt.xlabel('$N$')
plt.ylabel('$\\tau,\\ \\text{ns}$')
plt.grid(True, alpha=0.3)
plt.legend()
# plt.ylim(0, 50)
# plt.xlim(0, 100000)
plt.savefig('abc_test_01_OX_diff.png')
plt.show()
